# %%
# to read data from csv, python provides csv module
import csv

# %% [markdown]
# To deal with files in Python, we use the open() function, it’s a built-in Python function. This function accepts two different arguments (inputs) in the parentheses, always in the following order:
# * the name of the file (as a string)
# * the mode of working with the file (as a string)
#
# The syntax to open a file in python is:
#
# file_obj = open(“filename”, “mode”)

# %%
f = open('clear.csv')
# 'f' is a file handler here

csv_reader = csv.reader(f)
print(csv_reader)
# Out:
# <_csv.reader object at 0x00000226FF546920>

# %% [markdown]
# Transforming/Changing the data.

# %%
assetsCode = ['Female']

# initialize empty list
clear_data = []

next(csv_reader, None)  # skips the headers

# read csv data row wise
for row in csv_reader:
    if(row[1] in assetsCode):  # check if current row consist of either 'BTC' or 'ETH' or 'XRP' or 'LTC' currency data      
        clear_data.append(row)
        
# print(csv_reader.line_num)
print(len(clear_data))
print(clear_data[0:2])
# Out:
# 1043
# [['0', 'Female', '21.0', '1.62', '64.0', 'yes', 'no', 'Normal_Weight'], ['1', 'Female', '21.0', '1.52', '56.0', 'yes', 'yes', 'Normal_Weight']]

# %% [markdown]
# Loading the data into SQL DB

# %%
import sqlite3

# connect function opens a connection to the SQLite database file, 
conn = sqlite3.connect('session.db') 
#Similarly we will make connection with other databases like Oracle, DB2 etc.

# %%
# Drop a table name Clear id it exists already
try:
    conn.execute('DROP TABLE IF EXISTS `Clear` ')
except Exception as e:
    print(str(e))

# %%
# Create a new Table named as Crypto
try:
    conn.execute('''
         CREATE TABLE Clear
         (ID           INTEGER PRIMARY KEY,
         Age           Float DEFAULT 0,
         Height        Float DEFAULT 0,
         Weight        Float DEFAULT 0,
         SMOKE         TEXT NOT NULL,
         NObeyesdad    TEXT NOT NULL);''')
    print ("Table created successfully");
except Exception as e:
    print(str(e))
    print('Table Creation Failed!!!!!')
finally:
    conn.close() # this closes the database connection
# Out:
# Table created successfully

# %%
# Some more transformations
clear_sql_data = [(row[2], row[3], row[4], row[6], row[7]) for row in clear_data]
clear_sql_data[:2]
# Out:
# [('21.0', '1.62', '64.0', 'no', 'Normal_Weight'),
#  ('21.0', '1.52', '56.0', 'yes', 'Normal_Weight')]

# %%
# lets make new connection to Insert crypto data in SQL DB
conn = sqlite3.connect('session.db')
cur = conn.cursor()
try:
    cur.executemany("INSERT INTO Clear(Age, Height, Weight, SMOKE, NObeyesdad) VALUES (?,?,?,?,?)", clear_sql_data)
    conn.commit()
    print('Data Inserted Successfully')
except Exception as e:
    print(str(e))
    print('Data Insertion Failed')
finally:
    conn.close()
# Out:
# Data Inserted Successfully

# %%
# Let's Read data from DB to verify it

conn = sqlite3.connect('session.db')
rows = conn.cursor().execute('Select * from Clear')

for row in rows:
    print(row)
# Out:
# (1, 21.0, 1.62, 64.0, 'no', 'Normal_Weight')
# (2, 21.0, 1.52, 56.0, 'yes', 'Normal_Weight')
# (3, 23.0, 1.5, 55.0, 'no', 'Normal_Weight')
# (4, 21.0, 1.72, 80.0, 'no', 'Overweight_Level_II')
# (5, 22.0, 1.7, 66.0, 'no', 'Normal_Weight')
# (6, 29.0, 1.53, 78.0, 'no', 'Obesity_Type_I')
# (7, 30.0, 1.71, 82.0, 'yes', 'Overweight_Level_II')
# (8, 23.0, 1.65, 70.0, 'no', 'Overweight_Level_I')
# (9, 52.0, 1.69, 87.0, 'yes', 'Obesity_Type_I')
# (10, 22.0, 1.65, 60.0, 'no', 'Normal_Weight')
# (11, 22.0, 1.6, 82.0, 'no', 'Obesity_Type_I')
# (12, 23.0, 1.6, 52.0, 'no', 'Normal_Weight')
# (13, 31.0, 1.58, 68.0, 'no', 'Overweight_Level_II')
# (14, 24.0, 1.77, 76.0, 'no', 'Normal_Weight')
# (15, 21.0, 1.5, 65.0, 'no', 'Overweight_Level_II')
# (16, 22.0, 1.56, 49.0, 'no', 'Normal_Weight')
# (17, 21.0, 1.6, 48.0, 'no', 'Normal_Weight')
# (18, 21.0, 1.75, 88.0, 'no', 'Overweight_Level_II')
# (19, 21.0, 1.67, 75.0, 'no', 'Overweight_Level_I')
# (20, 21.0, 1.66, 64.0, 'no', 'Normal_Weight')
# (21, 21.0, 1.53, 65.0, 'no', 'Overweight_Level_II')
# (22, 20.0, 1.66, 60.0, 'no', 'Normal_Weight')
# (23, 21.0, 1.55, 50.0, 'no', 'Normal_Weight')
# (24, 21.0, 1.61, 54.5, 'no', 'Normal_Weight')
# (25, 20.0, 1.5, 44.0, 'no', 'Normal_Weight')
# (26, 23.0, 1.64, 52.0, 'no', 'Normal_Weight')
# (27, 23.0, 1.63, 55.0, 'no', 'Normal_Weight')
# (28, 22.0, 1.6, 55.0, 'no', 'Normal_Weight')
# (29, 17.0, 1.65, 67.0, 'no', 'Normal_Weight')
# (30, 21.0, 1.55, 49.0, 'no', 'Normal_Weight')
# (31, 21.0, 1.66, 57.0, 'no', 'Normal_Weight')
# (32, 21.0, 1.62, 69.0, 'no', 'Overweight_Level_I')
# (33, 23.0, 1.65, 80.0, 'no', 'Overweight_Level_II')
# (34, 22.0, 1.67, 50.0, 'no', 'Insufficient_Weight')
# (35, 24.0, 1.65, 60.0, 'no', 'Normal_Weight')
# (36, 23.0, 1.63, 45.0, 'no', 'Insufficient_Weight')
# (37, 24.0, 1.6, 45.0, 'no', 'Insufficient_Weight')
# (38, 24.0, 1.7, 80.0, 'no', 'Overweight_Level_II')
# (39, 23.0, 1.65, 90.0, 'no', 'Obesity_Type_I')
# (40, 19.0, 1.63, 58.0, 'no', 'Normal_Weight')
# (41, 19.0, 1.6, 45.0, 'no', 'Insufficient_Weight')
# (42, 22.0, 1.65, 65.0, 'no', 'Normal_Weight')
# (43, 29.0, 1.7, 78.0, 'no', 'Overweight_Level_II')
# (44, 25.0, 1.63, 93.0, 'no', 'Obesity_Type_II')
# (45, 20.0, 1.61, 64.0, 'no', 'Normal_Weight')
# (46, 20.0, 1.6, 57.0, 'no', 'Normal_Weight')
# (47, 24.0, 1.6, 48.0, 'no', 'Normal_Weight')
# (48, 23.0, 1.66, 60.0, 'no', 'Normal_Weight')
# (49, 21.0, 1.52, 42.0, 'no', 'Insufficient_Weight')
# (50, 21.0, 1.52, 42.0, 'no', 'Insufficient_Weight')
# (51, 21.0, 1.69, 63.0, 'no', 'Normal_Weight')
# (52, 21.0, 1.55, 57.0, 'no', 'Normal_Weight')
# (53, 22.0, 1.65, 58.0, 'no', 'Normal_Weight')
# (54, 38.0, 1.56, 80.0, 'no', 'Obesity_Type_I')
# (55, 25.0, 1.57, 55.0, 'no', 'Normal_Weight')
# (56, 25.0, 1.57, 55.0, 'no', 'Normal_Weight')
# (57, 21.0, 1.65, 88.0, 'no', 'Obesity_Type_I')
# (58, 22.0, 1.58, 58.0, 'no', 'Normal_Weight')
# (59, 18.0, 1.56, 51.0, 'no', 'Normal_Weight')
# (60, 22.0, 1.5, 49.0, 'no', 'Normal_Weight')
# (61, 19.0, 1.61, 62.0, 'no', 'Normal_Weight')
# (62, 17.0, 1.75, 57.0, 'no', 'Normal_Weight')
# (63, 15.0, 1.65, 86.0, 'no', 'Obesity_Type_I')
# (64, 17.0, 1.7, 85.0, 'no', 'Overweight_Level_II')
# (65, 19.0, 1.63, 76.0, 'yes', 'Overweight_Level_II')
# (66, 23.0, 1.67, 75.0, 'yes', 'Overweight_Level_I')
# (67, 19.0, 1.65, 61.0, 'no', 'Normal_Weight')
# (68, 20.0, 1.58, 53.0, 'no', 'Normal_Weight')
# (69, 19.0, 1.65, 56.0, 'yes', 'Normal_Weight')
# (70, 61.0, 1.65, 66.0, 'no', 'Normal_Weight')
# (71, 34.0, 1.68, 75.0, 'no', 'Overweight_Level_I')
# (72, 24.0, 1.56, 51.0, 'no', 'Normal_Weight')
# (73, 36.0, 1.63, 80.0, 'no', 'Obesity_Type_I')
# (74, 27.0, 1.6, 61.0, 'no', 'Normal_Weight')
# (75, 32.0, 1.67, 90.0, 'no', 'Obesity_Type_I')
# (76, 30.0, 1.62, 59.0, 'no', 'Normal_Weight')
# (77, 38.0, 1.5, 60.0, 'yes', 'Overweight_Level_I')
# (78, 31.0, 1.68, 63.0, 'no', 'Normal_Weight')
# (79, 35.0, 1.53, 45.0, 'no', 'Normal_Weight')
# (80, 40.0, 1.55, 62.0, 'no', 'Overweight_Level_I')
# (81, 21.0, 1.63, 60.0, 'yes', 'Normal_Weight')
# (82, 29.0, 1.74, 72.0, 'no', 'Normal_Weight')
# (83, 22.0, 1.73, 79.0, 'no', 'Overweight_Level_I')
# (84, 45.0, 1.63, 77.0, 'no', 'Overweight_Level_II')
# (85, 23.0, 1.65, 59.0, 'no', 'Normal_Weight')
# (86, 38.0, 1.64, 59.8, 'no', 'Normal_Weight')
# (87, 18.0, 1.57, 48.0, 'no', 'Normal_Weight')
# (88, 18.0, 1.58, 48.0, 'no', 'Normal_Weight')
# (89, 23.0, 1.68, 67.0, 'no', 'Normal_Weight')
# (90, 22.0, 1.68, 52.0, 'no', 'Insufficient_Weight')
# (91, 23.0, 1.48, 60.0, 'yes', 'Overweight_Level_II')
# (92, 31.0, 1.62, 68.0, 'no', 'Overweight_Level_I')
# (93, 33.0, 1.63, 62.0, 'no', 'Normal_Weight')
# (94, 23.0, 1.6, 83.0, 'no', 'Obesity_Type_I')
# (95, 18.0, 1.59, 40.0, 'no', 'Insufficient_Weight')
# (96, 23.0, 1.66, 60.0, 'no', 'Normal_Weight')
# (97, 23.0, 1.63, 83.0, 'yes', 'Obesity_Type_I')
# (98, 41.0, 1.54, 80.0, 'no', 'Obesity_Type_I')
# (99, 26.0, 1.56, 102.0, 'yes', 'Obesity_Type_III')
# (100, 23.0, 1.6, 78.0, 'yes', 'Obesity_Type_I')
# (101, 22.0, 1.69, 65.0, 'no', 'Normal_Weight')
# (102, 22.0, 1.69, 65.0, 'no', 'Normal_Weight')
# (103, 21.0, 1.63, 51.0, 'no', 'Normal_Weight')
# (104, 24.0, 1.5, 63.0, 'no', 'Overweight_Level_II')
# (105, 23.0, 1.6, 63.0, 'no', 'Normal_Weight')
# (106, 21.0, 1.5, 42.3, 'no', 'Normal_Weight')
# (107, 21.0, 1.6, 68.0, 'no', 'Overweight_Level_I')
# (108, 21.0, 1.75, 78.0, 'no', 'Overweight_Level_I')
# (109, 21.0, 1.72, 66.5, 'no', 'Normal_Weight')
# (110, 22.0, 1.61, 63.0, 'no', 'Normal_Weight')
# (111, 23.0, 1.63, 82.0, 'no', 'Obesity_Type_I')
# (112, 20.0, 1.6, 50.0, 'no', 'Normal_Weight')
# (113, 24.0, 1.62, 58.0, 'no', 'Normal_Weight')
# (114, 40.0, 1.68, 80.0, 'no', 'Overweight_Level_II')
# (115, 21.0, 1.63, 66.0, 'yes', 'Normal_Weight')
# (116, 51.0, 1.59, 50.0, 'yes', 'Normal_Weight')
# (117, 34.0, 1.68, 77.0, 'no', 'Overweight_Level_II')
# (118, 19.0, 1.59, 49.0, 'no', 'Normal_Weight')
# (119, 19.0, 1.69, 70.0, 'no', 'Normal_Weight')
# (120, 21.0, 1.66, 59.0, 'no', 'Normal_Weight')
# (121, 19.0, 1.64, 53.0, 'no', 'Normal_Weight')
# (122, 20.0, 1.62, 53.0, 'no', 'Normal_Weight')
# (123, 19.0, 1.7, 64.0, 'no', 'Normal_Weight')
# (124, 17.0, 1.63, 65.0, 'no', 'Normal_Weight')
# (125, 20.0, 1.63, 64.0, 'no', 'Normal_Weight')
# (126, 21.0, 1.54, 49.0, 'no', 'Normal_Weight')
# (127, 20.0, 1.64, 49.0, 'yes', 'Insufficient_Weight')
# (128, 20.0, 1.57, 60.0, 'no', 'Normal_Weight')
# (129, 20.0, 1.62, 52.0, 'no', 'Normal_Weight')
# (130, 20.0, 1.65, 75.0, 'no', 'Overweight_Level_II')
# (131, 26.0, 1.59, 47.0, 'no', 'Normal_Weight')
# (132, 22.0, 1.64, 56.0, 'no', 'Normal_Weight')
# (133, 18.0, 1.67, 91.0, 'no', 'Obesity_Type_I')
# (134, 28.0, 1.7, 73.0, 'no', 'Overweight_Level_I')
# (135, 39.0, 1.65, 50.0, 'no', 'Insufficient_Weight')
# (136, 19.0, 1.5, 50.0, 'no', 'Normal_Weight')
# (137, 25.0, 1.61, 61.0, 'no', 'Normal_Weight')
# (138, 18.0, 1.5, 50.0, 'no', 'Normal_Weight')
# (139, 32.0, 1.57, 57.0, 'no', 'Normal_Weight')
# (140, 18.0, 1.62, 55.0, 'no', 'Normal_Weight')
# (141, 21.0, 1.6, 61.0, 'no', 'Normal_Weight')
# (142, 18.0, 1.6, 58.0, 'no', 'Normal_Weight')
# (143, 17.0, 1.56, 51.0, 'no', 'Normal_Weight')
# (144, 16.0, 1.66, 58.0, 'no', 'Normal_Weight')
# (145, 21.0, 1.53, 53.0, 'no', 'Normal_Weight')
# (146, 16.0, 1.57, 49.0, 'no', 'Normal_Weight')
# (147, 24.0, 1.56, 60.0, 'no', 'Normal_Weight')
# (148, 23.0, 1.59, 48.0, 'no', 'Normal_Weight')
# (149, 16.0, 1.66, 58.0, 'no', 'Normal_Weight')
# (150, 16.0, 1.6, 57.0, 'no', 'Normal_Weight')
# (151, 26.0, 1.65, 63.0, 'no', 'Normal_Weight')
# (152, 25.0, 1.56, 45.0, 'no', 'Normal_Weight')
# (153, 27.0, 1.55, 63.0, 'no', 'Overweight_Level_I')
# (154, 23.0, 1.75, 56.0, 'no', 'Insufficient_Weight')
# (155, 30.0, 1.65, 71.0, 'no', 'Overweight_Level_I')
# (156, 21.0, 1.55, 58.0, 'no', 'Normal_Weight')
# (157, 19.0, 1.65, 82.0, 'no', 'Obesity_Type_I')
# (158, 17.0, 1.8, 50.0, 'no', 'Insufficient_Weight')
# (159, 23.0, 1.7, 56.0, 'no', 'Normal_Weight')
# (160, 18.0, 1.45, 53.0, 'no', 'Overweight_Level_I')
# (161, 17.0, 1.6, 65.0, 'no', 'Overweight_Level_I')
# (162, 19.0, 1.53, 42.0, 'no', 'Insufficient_Weight')
# (163, 21.0, 1.54, 47.0, 'no', 'Normal_Weight')
# (164, 26.0, 1.65, 60.0, 'no', 'Normal_Weight')
# (165, 17.0, 1.6, 53.0, 'no', 'Normal_Weight')
# (166, 24.0, 1.6, 51.0, 'no', 'Normal_Weight')
# (167, 17.0, 1.6, 59.0, 'no', 'Normal_Weight')
# (168, 27.0, 1.55, 62.0, 'no', 'Overweight_Level_I')
# (169, 17.0, 1.7, 56.0, 'no', 'Normal_Weight')
# (170, 33.0, 1.56, 48.0, 'no', 'Normal_Weight')
# (171, 40.0, 1.56, 80.0, 'no', 'Obesity_Type_I')
# (172, 37.0, 1.65, 73.0, 'no', 'Overweight_Level_I')
# (173, 40.0, 1.58, 63.0, 'no', 'Overweight_Level_I')
# (174, 37.0, 1.68, 83.0, 'no', 'Overweight_Level_II')
# (175, 18.0, 1.62, 58.0, 'no', 'Normal_Weight')
# (176, 21.0, 1.54, 56.0, 'no', 'Normal_Weight')
# (177, 36.0, 1.58, 60.0, 'no', 'Normal_Weight')
# (178, 29.0, 1.6, 56.0, 'no', 'Normal_Weight')
# (179, 18.0, 1.6, 60.0, 'no', 'Normal_Weight')
# (180, 16.0, 1.55, 45.0, 'no', 'Normal_Weight')
# (181, 18.0, 1.59, 53.0, 'no', 'Normal_Weight')
# (182, 37.0, 1.5, 75.0, 'no', 'Obesity_Type_I')
# (183, 16.0, 1.61, 65.0, 'no', 'Overweight_Level_I')
# (184, 18.0, 1.7, 50.0, 'no', 'Insufficient_Weight')
# (185, 17.0, 1.53, 55.0, 'no', 'Normal_Weight')
# (186, 20.0, 1.54, 39.0, 'no', 'Insufficient_Weight')
# (187, 38.0, 1.55, 59.0, 'no', 'Normal_Weight')
# (188, 26.0, 1.66, 112.0, 'no', 'Obesity_Type_III')
# (189, 19.0, 1.51, 59.0, 'no', 'Overweight_Level_I')
# (190, 33.0, 1.55, 55.0, 'no', 'Normal_Weight')
# (191, 20.0, 1.6, 65.0, 'no', 'Overweight_Level_I')
# (192, 19.0, 1.61, 53.8, 'no', 'Normal_Weight')
# (193, 20.0, 1.67, 60.0, 'no', 'Normal_Weight')
# (194, 18.0, 1.6, 55.0, 'no', 'Normal_Weight')
# (195, 18.0, 1.64, 59.0, 'no', 'Normal_Weight')
# (196, 19.0, 1.76, 80.0, 'no', 'Overweight_Level_I')
# (197, 18.0, 1.56, 55.0, 'no', 'Normal_Weight')
# (198, 18.0, 1.6, 56.0, 'no', 'Normal_Weight')
# (199, 19.0, 1.67, 64.0, 'no', 'Normal_Weight')
# (200, 19.0, 1.6, 60.0, 'no', 'Normal_Weight')
# (201, 18.0, 1.55, 56.0, 'no', 'Normal_Weight')
# (202, 18.0, 1.55, 50.0, 'no', 'Normal_Weight')
# (203, 19.0, 1.51, 45.0, 'no', 'Normal_Weight')
# (204, 24.0, 1.6, 100.5, 'no', 'Obesity_Type_II')
# (205, 18.0, 1.63, 63.0, 'no', 'Normal_Weight')
# (206, 18.0, 1.62, 50.0, 'no', 'Normal_Weight')
# (207, 20.0, 1.68, 68.0, 'no', 'Normal_Weight')
# (208, 33.0, 1.59, 60.0, 'no', 'Normal_Weight')
# (209, 19.0, 1.5, 45.0, 'no', 'Normal_Weight')
# (210, 18.0, 1.62, 55.0, 'no', 'Normal_Weight')
# (211, 18.0, 1.6, 51.0, 'no', 'Normal_Weight')
# (212, 20.0, 1.62, 45.0, 'no', 'Insufficient_Weight')
# (213, 19.0, 1.54, 42.0, 'no', 'Insufficient_Weight')
# (214, 20.0, 1.56, 51.5, 'no', 'Normal_Weight')
# (215, 18.0, 1.6, 83.0, 'no', 'Obesity_Type_I')
# (216, 18.0, 1.54, 71.0, 'no', 'Overweight_Level_II')
# (217, 18.0, 1.63, 51.0, 'no', 'Normal_Weight')
# (218, 18.0, 1.62, 68.0, 'no', 'Overweight_Level_I')
# (219, 18.0, 1.71, 75.0, 'no', 'Overweight_Level_I')
# (220, 18.0, 1.64, 56.0, 'no', 'Normal_Weight')
# (221, 17.0, 1.58, 50.0, 'no', 'Normal_Weight')
# (222, 18.0, 1.57, 50.0, 'no', 'Normal_Weight')
# (223, 20.0, 1.58, 53.5, 'no', 'Normal_Weight')
# (224, 18.0, 1.5, 58.0, 'no', 'Overweight_Level_I')
# (225, 36.0, 1.65, 80.0, 'no', 'Overweight_Level_II')
# (226, 19.0, 1.56, 50.0, 'no', 'Normal_Weight')
# (227, 18.0, 1.67, 66.0, 'no', 'Normal_Weight')
# (228, 25.196214, 1.686306, 104.572712, 'no', 'Obesity_Type_III')
# (229, 18.503343, 1.683124, 126.67378, 'no', 'Obesity_Type_III')
# (230, 26.0, 1.622397, 110.79263, 'no', 'Obesity_Type_III')
# (231, 21.853826, 1.755643, 137.796884, 'no', 'Obesity_Type_III')
# (232, 21.90012, 1.843419, 165.057269, 'no', 'Obesity_Type_III')
# (233, 18.306615, 1.7456, 133.03441, 'no', 'Obesity_Type_III')
# (234, 26.0, 1.630927, 111.485516, 'no', 'Obesity_Type_III')
# (235, 26.0, 1.629191, 104.826776, 'no', 'Obesity_Type_III')
# (236, 21.849705, 1.770612, 133.963349, 'no', 'Obesity_Type_III')
# (237, 22.0, 1.675446, 51.154201, 'no', 'Insufficient_Weight')
# (238, 21.02497, 1.666203, 49.869791, 'no', 'Insufficient_Weight')
# (239, 22.038327, 1.711467, 51.965521, 'no', 'Insufficient_Weight')
# (240, 21.243142, 1.598019, 44.845655, 'no', 'Insufficient_Weight')
# (241, 22.142432, 1.59611, 42.848033, 'no', 'Insufficient_Weight')
# (242, 21.962426, 1.57206, 43.919835, 'no', 'Insufficient_Weight')
# (243, 21.491055, 1.586952, 43.087508, 'no', 'Insufficient_Weight')
# (244, 22.717943, 1.59559, 44.581159, 'no', 'Insufficient_Weight')
# (245, 23.501249, 1.6, 45.0, 'no', 'Insufficient_Weight')
# (246, 18.535075, 1.688025, 45.0, 'no', 'Insufficient_Weight')
# (247, 19.0, 1.556211, 42.339767, 'no', 'Insufficient_Weight')
# (248, 19.0, 1.564199, 42.096062, 'no', 'Insufficient_Weight')
# (249, 20.254534, 1.56948, 41.324558, 'no', 'Insufficient_Weight')
# (250, 21.0, 1.52, 42.0, 'no', 'Insufficient_Weight')
# (251, 20.225396, 1.550648, 44.641796, 'no', 'Insufficient_Weight')
# (252, 19.86997, 1.520997, 42.0, 'no', 'Insufficient_Weight')
# (253, 20.147114, 1.528011, 42.0, 'no', 'Insufficient_Weight')
# (254, 21.0, 1.52, 42.0, 'no', 'Insufficient_Weight')
# (255, 21.996523, 1.733263, 50.890363, 'no', 'Insufficient_Weight')
# (256, 21.376426, 1.722527, 50.833029, 'no', 'Insufficient_Weight')
# (257, 19.724106, 1.734832, 50.0, 'no', 'Insufficient_Weight')
# (258, 18.871794, 1.586895, 41.452385, 'no', 'Insufficient_Weight')
# (259, 18.766033, 1.579561, 41.890204, 'no', 'Insufficient_Weight')
# (260, 18.540535, 1.564568, 41.397378, 'no', 'Insufficient_Weight')
# (261, 19.88036, 1.670635, 49.742931, 'no', 'Insufficient_Weight')
# (262, 19.717249, 1.688426, 49.660995, 'no', 'Insufficient_Weight')
# (263, 19.633898, 1.66084, 49.039794, 'no', 'Insufficient_Weight')
# (264, 23.0, 1.710182, 50.287967, 'no', 'Insufficient_Weight')
# (265, 20.406871, 1.755978, 53.699561, 'no', 'Insufficient_Weight')
# (266, 23.0, 1.728834, 51.442293, 'no', 'Insufficient_Weight')
# (267, 19.058511, 1.662017, 49.838965, 'no', 'Insufficient_Weight')
# (268, 18.827008, 1.7, 50.0, 'no', 'Insufficient_Weight')
# (269, 19.314964, 1.661403, 49.932199, 'no', 'Insufficient_Weight')
# (270, 29.970445, 1.610863, 49.516027, 'no', 'Insufficient_Weight')
# (271, 32.383858, 1.640688, 46.655622, 'no', 'Insufficient_Weight')
# (272, 24.163526, 1.64603, 49.839685, 'no', 'Insufficient_Weight')
# (273, 17.082867, 1.640824, 43.365005, 'no', 'Insufficient_Weight')
# (274, 17.000433, 1.584951, 44.411801, 'no', 'Insufficient_Weight')
# (275, 16.270434, 1.818268, 47.124717, 'no', 'Insufficient_Weight')
# (276, 22.377998, 1.699568, 54.98774, 'no', 'Insufficient_Weight')
# (277, 20.954955, 1.759358, 55.01045, 'no', 'Insufficient_Weight')
# (278, 22.991668, 1.740295, 54.166453, 'no', 'Insufficient_Weight')
# (279, 19.300435, 1.739354, 49.649613, 'no', 'Insufficient_Weight')
# (280, 17.065445, 1.647811, 49.603807, 'no', 'Insufficient_Weight')
# (281, 19.084967, 1.768435, 49.597765, 'no', 'Insufficient_Weight')
# (282, 18.024853, 1.7, 50.0, 'no', 'Insufficient_Weight')
# (283, 19.833682, 1.699464, 49.676046, 'no', 'Insufficient_Weight')
# (284, 17.767432, 1.74379, 50.0, 'no', 'Insufficient_Weight')
# (285, 19.504696, 1.590317, 42.367615, 'no', 'Insufficient_Weight')
# (286, 19.950605, 1.527133, 42.0, 'no', 'Insufficient_Weight')
# (287, 19.0, 1.530875, 42.0, 'no', 'Insufficient_Weight')
# (288, 22.926352, 1.715597, 50.0, 'no', 'Insufficient_Weight')
# (289, 21.785351, 1.675054, 49.945233, 'no', 'Insufficient_Weight')
# (290, 23.0, 1.717601, 51.073918, 'no', 'Insufficient_Weight')
# (291, 17.402028, 1.710756, 50.0, 'no', 'Insufficient_Weight')
# (292, 18.0, 1.7, 50.0, 'no', 'Insufficient_Weight')
# (293, 18.48207, 1.7, 50.0, 'no', 'Insufficient_Weight')
# (294, 18.53084, 1.573816, 39.850137, 'no', 'Insufficient_Weight')
# (295, 19.94814, 1.530884, 39.371523, 'no', 'Insufficient_Weight')
# (296, 20.400053, 1.529724, 40.343463, 'no', 'Insufficient_Weight')
# (297, 19.010211, 1.555431, 44.188767, 'no', 'Insufficient_Weight')
# (298, 19.091346, 1.603923, 45.0, 'no', 'Insufficient_Weight')
# (299, 19.773303, 1.602082, 45.0, 'no', 'Insufficient_Weight')
# (300, 19.483036, 1.53777, 42.0, 'no', 'Insufficient_Weight')
# (301, 19.0, 1.538398, 42.0, 'no', 'Insufficient_Weight')
# (302, 19.407204, 1.520862, 42.0, 'no', 'Insufficient_Weight')
# (303, 21.798856, 1.672007, 49.980968, 'no', 'Insufficient_Weight')
# (304, 22.209706, 1.593847, 44.050251, 'no', 'Insufficient_Weight')
# (305, 23.018443, 1.584785, 44.376637, 'no', 'Insufficient_Weight')
# (306, 19.376997, 1.600264, 45.0, 'no', 'Insufficient_Weight')
# (307, 20.971429, 1.549311, 41.557468, 'no', 'Insufficient_Weight')
# (308, 20.345161, 1.534385, 41.96525, 'no', 'Insufficient_Weight')
# (309, 20.519916, 1.725548, 49.815599, 'no', 'Insufficient_Weight')
# (310, 21.478496, 1.686936, 51.256059, 'no', 'Insufficient_Weight')
# (311, 18.372563, 1.589829, 40.202773, 'no', 'Insufficient_Weight')
# (312, 19.931667, 1.653209, 49.026214, 'no', 'Insufficient_Weight')
# (313, 22.998709, 1.740108, 53.65727, 'no', 'Insufficient_Weight')
# (314, 18.006742, 1.7, 50.0, 'no', 'Insufficient_Weight')
# (315, 34.799519, 1.689141, 50.0, 'no', 'Insufficient_Weight')
# (316, 16.611837, 1.830068, 43.534531, 'no', 'Insufficient_Weight')
# (317, 22.970655, 1.751691, 55.967655, 'no', 'Insufficient_Weight')
# (318, 17.764764, 1.78656, 50.0, 'no', 'Insufficient_Weight')
# (319, 19.272573, 1.71367, 50.0, 'no', 'Insufficient_Weight')
# (320, 19.0, 1.540375, 42.006282, 'no', 'Insufficient_Weight')
# (321, 23.0, 1.710129, 50.079991, 'no', 'Insufficient_Weight')
# (322, 18.0, 1.704193, 50.631889, 'no', 'Insufficient_Weight')
# (323, 19.054008, 1.556611, 39.695295, 'no', 'Insufficient_Weight')
# (324, 20.172661, 1.605521, 44.661461, 'no', 'Insufficient_Weight')
# (325, 19.220108, 1.530266, 42.0, 'no', 'Insufficient_Weight')
# (326, 21.125098, 1.767479, 56.265959, 'no', 'Insufficient_Weight')
# (327, 22.033129, 1.704223, 51.437985, 'no', 'Insufficient_Weight')
# (328, 20.744839, 1.667852, 49.803921, 'no', 'Insufficient_Weight')
# (329, 22.547298, 1.722461, 51.881263, 'no', 'Insufficient_Weight')
# (330, 21.837996, 1.588046, 44.236067, 'no', 'Insufficient_Weight')
# (331, 23.035829, 1.598612, 42.993937, 'no', 'Insufficient_Weight')
# (332, 21.529439, 1.592379, 44.00945, 'no', 'Insufficient_Weight')
# (333, 21.287999, 1.555778, 42.3601, 'no', 'Insufficient_Weight')
# (334, 23.444286, 1.596466, 44.594588, 'no', 'Insufficient_Weight')
# (335, 22.329041, 1.598393, 44.918255, 'no', 'Insufficient_Weight')
# (336, 18.91505, 1.633316, 45.0, 'no', 'Insufficient_Weight')
# (337, 19.0, 1.559567, 42.12617, 'no', 'Insufficient_Weight')
# (338, 19.052833, 1.546551, 42.069992, 'no', 'Insufficient_Weight')
# (339, 19.59904, 1.566501, 41.706283, 'no', 'Insufficient_Weight')
# (340, 21.0, 1.52, 42.0, 'no', 'Insufficient_Weight')
# (341, 19.673262, 1.599486, 44.810751, 'no', 'Insufficient_Weight')
# (342, 20.244359, 1.559186, 41.952805, 'no', 'Insufficient_Weight')
# (343, 20.552695, 1.523426, 42.0, 'no', 'Insufficient_Weight')
# (344, 21.0, 1.52, 42.0, 'no', 'Insufficient_Weight')
# (345, 21.997683, 1.689441, 51.107925, 'no', 'Insufficient_Weight')
# (346, 21.274628, 1.737453, 50.479039, 'no', 'Insufficient_Weight')
# (347, 18.909439, 1.732096, 50.0, 'no', 'Insufficient_Weight')
# (348, 21.813083, 1.712515, 51.710723, 'no', 'Insufficient_Weight')
# (349, 18.874591, 1.533609, 41.669346, 'no', 'Insufficient_Weight')
# (350, 19.21164, 1.567981, 41.934368, 'no', 'Insufficient_Weight')
# (351, 18.988581, 1.544263, 41.535047, 'no', 'Insufficient_Weight')
# (352, 19.408999, 1.670552, 49.804245, 'no', 'Insufficient_Weight')
# (353, 19.665881, 1.676346, 49.105025, 'no', 'Insufficient_Weight')
# (354, 19.758286, 1.667404, 49.125955, 'no', 'Insufficient_Weight')
# (355, 22.422674, 1.70011, 50.173425, 'no', 'Insufficient_Weight')
# (356, 22.637018, 1.703584, 51.607091, 'no', 'Insufficient_Weight')
# (357, 19.007177, 1.690727, 49.895716, 'no', 'Insufficient_Weight')
# (358, 18.288205, 1.713564, 50.0, 'no', 'Insufficient_Weight')
# (359, 19.314429, 1.67231, 49.713944, 'no', 'Insufficient_Weight')
# (360, 27.14823, 1.660446, 49.558304, 'no', 'Insufficient_Weight')
# (361, 25.380557, 1.630379, 46.062954, 'no', 'Insufficient_Weight')
# (362, 22.867719, 1.655413, 50.424661, 'no', 'Insufficient_Weight')
# (363, 16.834813, 1.74402, 50.0, 'no', 'Insufficient_Weight')
# (364, 18.595614, 1.609495, 42.656563, 'no', 'Insufficient_Weight')
# (365, 16.613108, 1.777929, 44.762023, 'no', 'Insufficient_Weight')
# (366, 16.928791, 1.710948, 45.248627, 'no', 'Insufficient_Weight')
# (367, 22.935612, 1.732307, 54.835576, 'no', 'Insufficient_Weight')
# (368, 22.99368, 1.741377, 54.877111, 'no', 'Insufficient_Weight')
# (369, 19.317148, 1.731195, 49.650897, 'no', 'Insufficient_Weight')
# (370, 16.910997, 1.74823, 49.928447, 'no', 'Insufficient_Weight')
# (371, 19.071027, 1.756865, 49.699672, 'no', 'Insufficient_Weight')
# (372, 18.019572, 1.701378, 50.088468, 'no', 'Insufficient_Weight')
# (373, 19.735968, 1.699956, 49.98297, 'no', 'Insufficient_Weight')
# (374, 18.094079, 1.723328, 50.0, 'no', 'Insufficient_Weight')
# (375, 19.054938, 1.585886, 42.541794, 'no', 'Insufficient_Weight')
# (376, 20.850119, 1.524926, 42.0, 'no', 'Insufficient_Weight')
# (377, 19.349258, 1.52337, 42.0, 'no', 'Insufficient_Weight')
# (378, 21.310907, 1.72064, 50.0, 'no', 'Insufficient_Weight')
# (379, 21.708354, 1.704167, 50.165754, 'no', 'Insufficient_Weight')
# (380, 22.176922, 1.71746, 51.491957, 'no', 'Insufficient_Weight')
# (381, 17.823438, 1.708406, 50.0, 'no', 'Insufficient_Weight')
# (382, 18.0, 1.763465, 50.279053, 'no', 'Insufficient_Weight')
# (383, 18.281092, 1.7, 50.0, 'no', 'Insufficient_Weight')
# (384, 18.656912, 1.574017, 41.220175, 'no', 'Insufficient_Weight')
# (385, 19.994543, 1.537739, 39.101805, 'no', 'Insufficient_Weight')
# (386, 20.255616, 1.534223, 41.268597, 'no', 'Insufficient_Weight')
# (387, 19.029494, 1.573987, 44.316254, 'no', 'Insufficient_Weight')
# (388, 19.269079, 1.58092, 44.753943, 'no', 'Insufficient_Weight')
# (389, 19.946244, 1.603435, 45.0, 'no', 'Insufficient_Weight')
# (390, 19.639431, 1.53535, 42.0, 'no', 'Insufficient_Weight')
# (391, 19.0, 1.53161, 42.0, 'no', 'Insufficient_Weight')
# (392, 19.434709, 1.525691, 42.0, 'no', 'Insufficient_Weight')
# (393, 41.823567, 1.721854, 82.919584, 'no', 'Overweight_Level_I')
# (394, 18.836315, 1.751631, 80.0, 'no', 'Overweight_Level_I')
# (395, 33.700749, 1.642971, 74.803157, 'no', 'Overweight_Level_I')
# (396, 21.845025, 1.613668, 68.126955, 'no', 'Overweight_Level_I')
# (397, 35.125401, 1.529834, 62.903938, 'no', 'Overweight_Level_I')
# (398, 36.769646, 1.55, 62.337721, 'no', 'Overweight_Level_I')
# (399, 21.868932, 1.731261, 78.175706, 'no', 'Overweight_Level_I')
# (400, 30.958957, 1.633491, 68.803694, 'no', 'Overweight_Level_I')
# (401, 22.667596, 1.718939, 75.951472, 'no', 'Overweight_Level_I')
# (402, 21.81119, 1.6, 66.401407, 'no', 'Overweight_Level_I')
# (403, 21.0, 1.754813, 77.929204, 'no', 'Overweight_Level_I')
# (404, 29.08107, 1.674568, 71.602622, 'no', 'Overweight_Level_I')
# (405, 24.023972, 1.599697, 64.808022, 'no', 'Overweight_Level_I')
# (406, 32.593129, 1.721903, 72.748903, 'no', 'Overweight_Level_I')
# (407, 16.941489, 1.551288, 54.93242, 'no', 'Overweight_Level_I')
# (408, 16.172992, 1.603842, 65.0, 'no', 'Overweight_Level_I')
# (409, 23.71259, 1.588597, 62.339003, 'no', 'Overweight_Level_I')
# (410, 35.194089, 1.673482, 73.193589, 'no', 'Overweight_Level_I')
# (411, 37.218161, 1.593894, 63.320629, 'no', 'Overweight_Level_I')
# (412, 16.30687, 1.616366, 67.183128, 'no', 'Overweight_Level_I')
# (413, 18.297229, 1.637396, 70.0, 'no', 'Overweight_Level_I')
# (414, 18.610761, 1.550723, 60.628321, 'no', 'Overweight_Level_I')
# (415, 17.451085, 1.6, 65.0, 'no', 'Overweight_Level_I')
# (416, 31.539393, 1.657496, 73.641633, 'no', 'Overweight_Level_I')
# (417, 19.0, 1.76, 79.544998, 'no', 'Overweight_Level_I')
# (418, 18.0, 1.644682, 68.392133, 'no', 'Overweight_Level_I')
# (419, 18.270434, 1.737165, 76.699774, 'no', 'Overweight_Level_I')
# (420, 19.816228, 1.507853, 64.259379, 'no', 'Overweight_Level_I')
# (421, 21.012542, 1.615145, 68.653347, 'no', 'Overweight_Level_I')
# (422, 21.071195, 1.616467, 68.77185, 'no', 'Overweight_Level_I')
# (423, 42.24475, 1.768231, 75.62931, 'no', 'Overweight_Level_I')
# (424, 32.997118, 1.672446, 74.812707, 'no', 'Overweight_Level_I')
# (425, 32.501143, 1.675979, 74.959747, 'no', 'Overweight_Level_I')
# (426, 21.938831, 1.611239, 67.939653, 'no', 'Overweight_Level_I')
# (427, 21.909534, 1.611356, 68.06609, 'no', 'Overweight_Level_I')
# (428, 37.455752, 1.508908, 63.183846, 'no', 'Overweight_Level_I')
# (429, 40.0, 1.561109, 62.871794, 'no', 'Overweight_Level_I')
# (430, 38.943282, 1.554728, 63.011645, 'no', 'Overweight_Level_I')
# (431, 21.987341, 1.730182, 78.55444, 'no', 'Overweight_Level_I')
# (432, 21.198217, 1.743841, 78.88036, 'no', 'Overweight_Level_I')
# (433, 29.32038, 1.642506, 69.906708, 'no', 'Overweight_Level_I')
# (434, 31.255587, 1.69308, 71.927379, 'no', 'Overweight_Level_I')
# (435, 21.687409, 1.604697, 68.016472, 'no', 'Overweight_Level_I')
# (436, 21.455463, 1.611, 68.107866, 'no', 'Overweight_Level_I')
# (437, 21.0, 1.754497, 77.956921, 'no', 'Overweight_Level_I')
# (438, 21.0, 1.752944, 77.965532, 'no', 'Overweight_Level_I')
# (439, 21.012569, 1.758628, 78.370039, 'no', 'Overweight_Level_I')
# (440, 21.016623, 1.755427, 78.300084, 'no', 'Overweight_Level_I')
# (441, 19.0, 1.779882, 80.091886, 'no', 'Overweight_Level_I')
# (442, 27.899784, 1.7, 74.244004, 'no', 'Overweight_Level_I')
# (443, 21.832995, 1.580964, 65.363941, 'no', 'Overweight_Level_I')
# (444, 30.255744, 1.652084, 73.575981, 'no', 'Overweight_Level_I')
# (445, 30.613586, 1.645511, 69.168978, 'no', 'Overweight_Level_I')
# (446, 18.0, 1.456346, 55.523481, 'no', 'Overweight_Level_I')
# (447, 18.0, 1.498561, 55.376512, 'no', 'Overweight_Level_I')
# (448, 16.950499, 1.603501, 65.0, 'no', 'Overweight_Level_I')
# (449, 21.837058, 1.558045, 63.597633, 'no', 'Overweight_Level_I')
# (450, 27.0, 1.55, 62.877347, 'no', 'Overweight_Level_I')
# (451, 35.483601, 1.647514, 73.91692, 'no', 'Overweight_Level_I')
# (452, 40.0, 1.570811, 62.211572, 'no', 'Overweight_Level_I')
# (453, 16.38009, 1.617124, 67.913561, 'no', 'Overweight_Level_I')
# (454, 16.865984, 1.644053, 67.439589, 'no', 'Overweight_Level_I')
# (455, 16.093234, 1.608914, 65.0, 'no', 'Overweight_Level_I')
# (456, 18.0, 1.647971, 68.818893, 'no', 'Overweight_Level_I')
# (457, 18.83919, 1.624831, 69.975607, 'no', 'Overweight_Level_I')
# (458, 19.726522, 1.508267, 61.10403, 'no', 'Overweight_Level_I')
# (459, 18.947102, 1.518917, 60.267427, 'no', 'Overweight_Level_I')
# (460, 17.781183, 1.6, 65.0, 'no', 'Overweight_Level_I')
# (461, 33.251015, 1.730379, 75.920519, 'no', 'Overweight_Level_I')
# (462, 18.985119, 1.759117, 80.0, 'no', 'Overweight_Level_I')
# (463, 18.871917, 1.755254, 80.0, 'no', 'Overweight_Level_I')
# (464, 20.979254, 1.75655, 78.721696, 'no', 'Overweight_Level_I')
# (465, 18.869151, 1.756774, 79.989789, 'no', 'Overweight_Level_I')
# (466, 18.236087, 1.62, 69.3899, 'no', 'Overweight_Level_I')
# (467, 20.901393, 1.709585, 75.0, 'no', 'Overweight_Level_I')
# (468, 17.08525, 1.535618, 57.259124, 'no', 'Overweight_Level_I')
# (469, 21.0, 1.618148, 68.981403, 'no', 'Overweight_Level_I')
# (470, 38.939448, 1.738321, 86.934846, 'no', 'Overweight_Level_I')
# (471, 39.965474, 1.739293, 80.914382, 'no', 'Overweight_Level_I')
# (472, 18.845518, 1.753471, 80.0, 'no', 'Overweight_Level_I')
# (473, 33.732714, 1.679725, 74.885222, 'no', 'Overweight_Level_I')
# (474, 21.571288, 1.600914, 68.058902, 'no', 'Overweight_Level_I')
# (475, 21.165574, 1.617749, 68.908136, 'no', 'Overweight_Level_I')
# (476, 38.692265, 1.548178, 62.341438, 'no', 'Overweight_Level_I')
# (477, 38.952866, 1.568441, 62.855073, 'no', 'Overweight_Level_I')
# (478, 36.631456, 1.532322, 62.417228, 'no', 'Overweight_Level_I')
# (479, 21.996118, 1.730199, 78.997062, 'no', 'Overweight_Level_I')
# (480, 21.951309, 1.730167, 78.429312, 'no', 'Overweight_Level_I')
# (481, 29.934465, 1.638744, 69.242354, 'no', 'Overweight_Level_I')
# (482, 31.166572, 1.680858, 71.81338, 'no', 'Overweight_Level_I')
# (483, 20.534606, 1.758372, 79.469513, 'no', 'Overweight_Level_I')
# (484, 21.009437, 1.60681, 67.773914, 'no', 'Overweight_Level_I')
# (485, 21.538225, 1.610327, 67.999778, 'no', 'Overweight_Level_I')
# (486, 21.814653, 1.611822, 67.140367, 'no', 'Overweight_Level_I')
# (487, 21.979769, 1.6, 66.126964, 'no', 'Overweight_Level_I')
# (488, 21.0, 1.753578, 77.97917, 'no', 'Overweight_Level_I')
# (489, 21.0285, 1.742364, 78.664618, 'no', 'Overweight_Level_I')
# (490, 29.463168, 1.659172, 71.170001, 'no', 'Overweight_Level_I')
# (491, 22.239836, 1.59994, 65.423942, 'no', 'Overweight_Level_I')
# (492, 31.62638, 1.666023, 72.906186, 'no', 'Overweight_Level_I')
# (493, 17.420269, 1.489409, 53.620604, 'no', 'Overweight_Level_I')
# (494, 17.807828, 1.518067, 55.822119, 'no', 'Overweight_Level_I')
# (495, 16.240576, 1.616533, 65.062945, 'no', 'Overweight_Level_I')
# (496, 23.252457, 1.589616, 65.127324, 'no', 'Overweight_Level_I')
# (497, 34.772902, 1.675612, 73.501233, 'no', 'Overweight_Level_I')
# (498, 39.214514, 1.580765, 62.631382, 'no', 'Overweight_Level_I')
# (499, 16.370009, 1.613921, 66.738769, 'no', 'Overweight_Level_I')
# (500, 17.992717, 1.618683, 67.193585, 'no', 'Overweight_Level_I')
# (501, 19.621545, 1.566524, 61.616, 'no', 'Overweight_Level_I')
# (502, 19.755797, 1.542328, 63.856193, 'no', 'Overweight_Level_I')
# (503, 17.099015, 1.6, 65.0, 'no', 'Overweight_Level_I')
# (504, 17.25813, 1.600184, 65.0, 'no', 'Overweight_Level_I')
# (505, 32.278869, 1.64602, 74.147443, 'no', 'Overweight_Level_I')
# (506, 31.793937, 1.65015, 73.810728, 'no', 'Overweight_Level_I')
# (507, 19.0, 1.76, 79.349221, 'no', 'Overweight_Level_I')
# (508, 18.0, 1.622241, 68.250249, 'no', 'Overweight_Level_I')
# (509, 18.003153, 1.729996, 75.816864, 'no', 'Overweight_Level_I')
# (510, 18.052394, 1.725233, 75.970712, 'no', 'Overweight_Level_I')
# (511, 19.774317, 1.541039, 64.726948, 'no', 'Overweight_Level_I')
# (512, 28.583944, 1.57856, 65.522744, 'no', 'Overweight_Level_II')
# (513, 20.392665, 1.525234, 65.220249, 'no', 'Overweight_Level_II')
# (514, 22.154854, 1.481682, 61.373868, 'no', 'Overweight_Level_II')
# (515, 20.70768, 1.569878, 69.743323, 'no', 'Overweight_Level_II')
# (516, 20.634694, 1.568188, 67.904023, 'no', 'Overweight_Level_II')
# (517, 22.909992, 1.700038, 80.0, 'no', 'Overweight_Level_II')
# (518, 23.0, 1.668649, 80.458343, 'no', 'Overweight_Level_II')
# (519, 25.461411, 1.7, 78.055968, 'no', 'Overweight_Level_II')
# (520, 28.830558, 1.7, 78.0, 'no', 'Overweight_Level_II')
# (521, 19.027574, 1.659877, 77.272652, 'no', 'Overweight_Level_II')
# (522, 25.19291, 1.7, 80.749657, 'no', 'Overweight_Level_II')
# (523, 26.595893, 1.660756, 78.574786, 'no', 'Overweight_Level_II')
# (524, 42.189023, 1.647768, 79.165306, 'no', 'Overweight_Level_II')
# (525, 28.770852, 1.532897, 65.031879, 'no', 'Overweight_Level_II')
# (526, 25.483381, 1.565288, 64.848627, 'no', 'Overweight_Level_II')
# (527, 21.67315, 1.5, 63.65233, 'no', 'Overweight_Level_II')
# (528, 23.469538, 1.507106, 64.814109, 'no', 'Overweight_Level_II')
# (529, 38.464538, 1.696423, 78.967919, 'no', 'Overweight_Level_II')
# (530, 37.496175, 1.653088, 80.0, 'no', 'Overweight_Level_II')
# (531, 33.690239, 1.681842, 77.426465, 'no', 'Overweight_Level_II')
# (532, 34.369686, 1.652202, 77.13322, 'no', 'Overweight_Level_II')
# (533, 18.863875, 1.560029, 71.728069, 'no', 'Overweight_Level_II')
# (534, 18.951144, 1.621048, 72.105856, 'no', 'Overweight_Level_II')
# (535, 34.389679, 1.691322, 77.561602, 'no', 'Overweight_Level_II')
# (536, 36.310292, 1.701397, 83.0, 'no', 'Overweight_Level_II')
# (537, 20.0, 1.625236, 74.433362, 'no', 'Overweight_Level_II')
# (538, 18.549437, 1.545196, 72.467862, 'no', 'Overweight_Level_II')
# (539, 19.911246, 1.530248, 68.85097, 'no', 'Overweight_Level_II')
# (540, 34.204408, 1.664927, 80.386078, 'no', 'Overweight_Level_II')
# (541, 34.281681, 1.673333, 77.205685, 'no', 'Overweight_Level_II')
# (542, 43.238402, 1.733875, 86.94538, 'no', 'Overweight_Level_II')
# (543, 45.0, 1.675953, 79.66832, 'no', 'Overweight_Level_II')
# (544, 30.711381, 1.536819, 65.912688, 'no', 'Overweight_Level_II')
# (545, 20.843363, 1.521008, 67.083121, 'no', 'Overweight_Level_II')
# (546, 20.492077, 1.529223, 65.140408, 'no', 'Overweight_Level_II')
# (547, 23.0, 1.681314, 80.037202, 'no', 'Overweight_Level_II')
# (548, 23.728707, 1.663509, 80.0, 'no', 'Overweight_Level_II')
# (549, 28.977792, 1.7, 78.0, 'no', 'Overweight_Level_II')
# (550, 19.126145, 1.633794, 77.858532, 'no', 'Overweight_Level_II')
# (551, 28.824194, 1.7, 78.0, 'no', 'Overweight_Level_II')
# (552, 28.167799, 1.658202, 78.0, 'no', 'Overweight_Level_II')
# (553, 38.378056, 1.67805, 77.224574, 'no', 'Overweight_Level_II')
# (554, 21.082384, 1.486484, 60.117993, 'no', 'Overweight_Level_II')
# (555, 25.293202, 1.503379, 64.342459, 'no', 'Overweight_Level_II')
# (556, 39.170029, 1.688354, 79.278896, 'no', 'Overweight_Level_II')
# (557, 34.044229, 1.665807, 77.098973, 'no', 'Overweight_Level_II')
# (558, 19.821996, 1.653431, 75.090439, 'no', 'Overweight_Level_II')
# (559, 38.384177, 1.698626, 78.637307, 'no', 'Overweight_Level_II')
# (560, 37.205173, 1.667469, 80.993373, 'no', 'Overweight_Level_II')
# (561, 19.027417, 1.588147, 73.939268, 'no', 'Overweight_Level_II')
# (562, 18.198322, 1.543338, 71.799982, 'no', 'Overweight_Level_II')
# (563, 35.456326, 1.651812, 79.437921, 'no', 'Overweight_Level_II')
# (564, 39.392569, 1.706349, 85.720788, 'no', 'Overweight_Level_II')
# (565, 22.989846, 1.65, 80.0, 'no', 'Overweight_Level_II')
# (566, 24.320154, 1.577921, 65.293179, 'no', 'Overweight_Level_II')
# (567, 21.001282, 1.517998, 64.696248, 'no', 'Overweight_Level_II')
# (568, 21.95994, 1.483284, 62.894283, 'no', 'Overweight_Level_II')
# (569, 19.090023, 1.562434, 70.442775, 'no', 'Overweight_Level_II')
# (570, 20.820455, 1.547066, 67.473282, 'no', 'Overweight_Level_II')
# (571, 22.980957, 1.700216, 80.473587, 'no', 'Overweight_Level_II')
# (572, 26.591628, 1.7, 78.008388, 'no', 'Overweight_Level_II')
# (573, 23.629159, 1.70002, 80.420434, 'no', 'Overweight_Level_II')
# (574, 26.208134, 1.7, 78.041338, 'no', 'Overweight_Level_II')
# (575, 23.586058, 1.700499, 81.108599, 'no', 'Overweight_Level_II')
# (576, 25.472995, 1.688911, 78.434492, 'no', 'Overweight_Level_II')
# (577, 41.743333, 1.67861, 79.849252, 'no', 'Overweight_Level_II')
# (578, 27.757187, 1.505437, 63.892071, 'no', 'Overweight_Level_II')
# (579, 25.113537, 1.505387, 63.715219, 'no', 'Overweight_Level_II')
# (580, 21.82165, 1.491441, 62.269912, 'no', 'Overweight_Level_II')
# (581, 20.670975, 1.509408, 64.852953, 'no', 'Overweight_Level_II')
# (582, 38.097395, 1.696954, 78.156035, 'no', 'Overweight_Level_II')
# (583, 37.642177, 1.676095, 79.079738, 'no', 'Overweight_Level_II')
# (584, 34.176795, 1.681021, 77.392179, 'no', 'Overweight_Level_II')
# (585, 34.231083, 1.654067, 79.697278, 'no', 'Overweight_Level_II')
# (586, 18.741188, 1.556789, 71.788181, 'no', 'Overweight_Level_II')
# (587, 19.955257, 1.5891, 72.713611, 'no', 'Overweight_Level_II')
# (588, 33.954433, 1.682253, 77.431678, 'no', 'Overweight_Level_II')
# (589, 19.005725, 1.599999, 73.513873, 'no', 'Overweight_Level_II')
# (590, 18.850466, 1.550053, 72.9518, 'no', 'Overweight_Level_II')
# (591, 19.462713, 1.550122, 69.936073, 'no', 'Overweight_Level_II')
# (592, 35.432059, 1.663178, 80.135167, 'no', 'Overweight_Level_II')
# (593, 33.864257, 1.679299, 77.355417, 'no', 'Overweight_Level_II')
# (594, 45.821267, 1.687326, 80.413997, 'no', 'Overweight_Level_II')
# (595, 31.386405, 1.556579, 78.233341, 'no', 'Obesity_Type_I')
# (596, 25.706285, 1.585547, 80.351263, 'no', 'Obesity_Type_I')
# (597, 43.604901, 1.569234, 81.827288, 'no', 'Obesity_Type_I')
# (598, 42.31607, 1.583943, 81.936398, 'no', 'Obesity_Type_I')
# (599, 22.654316, 1.621233, 82.0, 'no', 'Obesity_Type_I')
# (600, 22.679935, 1.6084, 82.603984, 'no', 'Obesity_Type_I')
# (601, 22.596576, 1.650052, 87.272552, 'no', 'Obesity_Type_I')
# (602, 23.0, 1.644161, 84.340406, 'no', 'Obesity_Type_I')
# (603, 37.356288, 1.559499, 77.26813, 'no', 'Obesity_Type_I')
# (604, 22.025438, 1.640426, 87.344156, 'no', 'Obesity_Type_I')
# (605, 18.086772, 1.65, 82.13682, 'no', 'Obesity_Type_I')
# (606, 40.821515, 1.553026, 77.74518, 'no', 'Obesity_Type_I')
# (607, 37.955371, 1.560648, 80.0, 'no', 'Obesity_Type_I')
# (608, 22.061461, 1.6, 82.040318, 'no', 'Obesity_Type_I')
# (609, 23.0, 1.61082, 82.532994, 'no', 'Obesity_Type_I')
# (610, 23.0, 1.665199, 83.15115, 'no', 'Obesity_Type_I')
# (611, 40.951591, 1.542122, 80.0, 'no', 'Obesity_Type_I')
# (612, 39.135634, 1.507867, 79.58958, 'no', 'Obesity_Type_I')
# (613, 23.779235, 1.553127, 78.0, 'no', 'Obesity_Type_I')
# (614, 23.0, 1.615854, 80.615325, 'no', 'Obesity_Type_I')
# (615, 18.0, 1.685633, 90.032671, 'no', 'Obesity_Type_I')
# (616, 18.267696, 1.706343, 93.348843, 'no', 'Obesity_Type_I')
# (617, 19.442663, 1.627812, 82.0, 'no', 'Obesity_Type_I')
# (618, 22.865018, 1.632118, 82.0, 'no', 'Obesity_Type_I')
# (619, 37.832949, 1.610867, 80.0, 'no', 'Obesity_Type_I')
# (620, 37.631769, 1.513202, 75.410647, 'no', 'Obesity_Type_I')
# (621, 37.524551, 1.567915, 76.129784, 'no', 'Obesity_Type_I')
# (622, 43.510672, 1.587546, 76.126112, 'no', 'Obesity_Type_I')
# (623, 18.0, 1.670058, 86.242679, 'no', 'Obesity_Type_I')
# (624, 18.0, 1.609321, 84.493156, 'no', 'Obesity_Type_I')
# (625, 18.312665, 1.60074, 82.249831, 'no', 'Obesity_Type_I')
# (626, 30.163408, 1.533364, 78.030383, 'no', 'Obesity_Type_I')
# (627, 28.770039, 1.580858, 79.713492, 'no', 'Obesity_Type_I')
# (628, 42.337283, 1.64639, 86.639861, 'no', 'Obesity_Type_I')
# (629, 47.283374, 1.643786, 81.978743, 'no', 'Obesity_Type_I')
# (630, 22.518787, 1.634342, 82.414477, 'no', 'Obesity_Type_I')
# (631, 22.836315, 1.604893, 82.0, 'no', 'Obesity_Type_I')
# (632, 23.0, 1.634688, 82.628, 'no', 'Obesity_Type_I')
# (633, 23.0, 1.628168, 84.49798, 'no', 'Obesity_Type_I')
# (634, 38.148845, 1.557808, 79.661693, 'no', 'Obesity_Type_I')
# (635, 37.96543, 1.560199, 80.0, 'no', 'Obesity_Type_I')
# (636, 21.008051, 1.65, 88.126544, 'no', 'Obesity_Type_I')
# (637, 22.591026, 1.650012, 87.676154, 'no', 'Obesity_Type_I')
# (638, 16.129279, 1.65, 85.583485, 'no', 'Obesity_Type_I')
# (639, 16.913841, 1.634832, 85.803809, 'no', 'Obesity_Type_I')
# (640, 43.591999, 1.595165, 77.354744, 'no', 'Obesity_Type_I')
# (641, 40.993179, 1.567756, 79.493626, 'no', 'Obesity_Type_I')
# (642, 37.597953, 1.62901, 80.0, 'no', 'Obesity_Type_I')
# (643, 37.532066, 1.615385, 80.0, 'no', 'Obesity_Type_I')
# (644, 23.0, 1.608469, 82.954796, 'no', 'Obesity_Type_I')
# (645, 23.0, 1.630357, 83.1011, 'no', 'Obesity_Type_I')
# (646, 22.679454, 1.62826, 82.967937, 'no', 'Obesity_Type_I')
# (647, 22.480889, 1.605662, 82.470375, 'no', 'Obesity_Type_I')
# (648, 41.403862, 1.567973, 81.056851, 'no', 'Obesity_Type_I')
# (649, 40.702771, 1.548403, 80.0, 'no', 'Obesity_Type_I')
# (650, 23.474165, 1.577115, 78.0, 'no', 'Obesity_Type_I')
# (651, 24.317607, 1.586751, 79.109029, 'no', 'Obesity_Type_I')
# (652, 22.875223, 1.624367, 82.0, 'no', 'Obesity_Type_I')
# (653, 22.884722, 1.622787, 82.0, 'no', 'Obesity_Type_I')
# (654, 18.603496, 1.681719, 90.671871, 'no', 'Obesity_Type_I')
# (655, 21.106056, 1.722884, 92.949254, 'no', 'Obesity_Type_I')
# (656, 19.431662, 1.631662, 82.0, 'no', 'Obesity_Type_I')
# (657, 18.166318, 1.649553, 82.323954, 'no', 'Obesity_Type_I')
# (658, 39.213399, 1.586301, 80.0, 'no', 'Obesity_Type_I')
# (659, 38.098745, 1.598448, 80.0, 'no', 'Obesity_Type_I')
# (660, 38.547267, 1.526472, 75.150345, 'no', 'Obesity_Type_I')
# (661, 38.683794, 1.501993, 76.642944, 'no', 'Obesity_Type_I')
# (662, 18.0, 1.686904, 90.004046, 'no', 'Obesity_Type_I')
# (663, 18.107092, 1.703259, 91.499683, 'no', 'Obesity_Type_I')
# (664, 18.011903, 1.65, 84.210535, 'no', 'Obesity_Type_I')
# (665, 18.0, 1.649439, 84.897738, 'no', 'Obesity_Type_I')
# (666, 18.078256, 1.622999, 82.403076, 'no', 'Obesity_Type_I')
# (667, 18.063582, 1.633675, 82.459577, 'no', 'Obesity_Type_I')
# (668, 33.226808, 1.557943, 77.647716, 'no', 'Obesity_Type_I')
# (669, 26.220065, 1.560258, 78.435904, 'no', 'Obesity_Type_I')
# (670, 23.090215, 1.596586, 80.726195, 'no', 'Obesity_Type_I')
# (671, 24.565628, 1.62093, 81.718232, 'no', 'Obesity_Type_I')
# (672, 42.586285, 1.571417, 81.918809, 'no', 'Obesity_Type_I')
# (673, 43.719395, 1.584322, 80.986496, 'no', 'Obesity_Type_I')
# (674, 43.37634, 1.582523, 81.919454, 'no', 'Obesity_Type_I')
# (675, 39.648946, 1.572791, 80.086524, 'no', 'Obesity_Type_I')
# (676, 22.693989, 1.627908, 82.0, 'no', 'Obesity_Type_I')
# (677, 22.676243, 1.620938, 82.283185, 'no', 'Obesity_Type_I')
# (678, 22.804818, 1.613119, 82.636162, 'no', 'Obesity_Type_I')
# (679, 22.857123, 1.62686, 82.410189, 'no', 'Obesity_Type_I')
# (680, 21.02064, 1.65, 88.129437, 'no', 'Obesity_Type_I')
# (681, 21.001458, 1.65, 88.026943, 'no', 'Obesity_Type_I')
# (682, 22.87795, 1.66913, 86.002736, 'no', 'Obesity_Type_I')
# (683, 22.847618, 1.669136, 85.568385, 'no', 'Obesity_Type_I')
# (684, 23.0, 1.611058, 84.191125, 'no', 'Obesity_Type_I')
# (685, 23.0, 1.649736, 84.134712, 'no', 'Obesity_Type_I')
# (686, 39.129291, 1.532643, 77.550345, 'no', 'Obesity_Type_I')
# (687, 37.441044, 1.524293, 76.202761, 'no', 'Obesity_Type_I')
# (688, 21.895468, 1.64456, 88.119139, 'no', 'Obesity_Type_I')
# (689, 21.3928, 1.641149, 88.079177, 'no', 'Obesity_Type_I')
# (690, 18.178076, 1.642892, 82.144405, 'no', 'Obesity_Type_I')
# (691, 18.907514, 1.65, 82.01831, 'no', 'Obesity_Type_I')
# (692, 40.466313, 1.559005, 77.601483, 'no', 'Obesity_Type_I')
# (693, 38.445148, 1.556028, 77.684229, 'no', 'Obesity_Type_I')
# (694, 38.397463, 1.552648, 80.0, 'no', 'Obesity_Type_I')
# (695, 37.974483, 1.560215, 80.0, 'no', 'Obesity_Type_I')
# (696, 22.226815, 1.609068, 83.785312, 'no', 'Obesity_Type_I')
# (697, 22.538932, 1.603963, 82.012637, 'no', 'Obesity_Type_I')
# (698, 22.307413, 1.605495, 82.528575, 'no', 'Obesity_Type_I')
# (699, 22.362877, 1.607182, 82.368441, 'no', 'Obesity_Type_I')
# (700, 22.89974, 1.661715, 82.595793, 'no', 'Obesity_Type_I')
# (701, 22.997168, 1.655742, 82.46376, 'no', 'Obesity_Type_I')
# (702, 38.895069, 1.549257, 80.0, 'no', 'Obesity_Type_I')
# (703, 40.789529, 1.549748, 80.0, 'no', 'Obesity_Type_I')
# (704, 40.654155, 1.52906, 79.760922, 'no', 'Obesity_Type_I')
# (705, 38.542937, 1.517248, 79.843221, 'no', 'Obesity_Type_I')
# (706, 23.803904, 1.581527, 78.089575, 'no', 'Obesity_Type_I')
# (707, 23.652435, 1.562724, 80.535698, 'no', 'Obesity_Type_I')
# (708, 23.099906, 1.571812, 78.997166, 'no', 'Obesity_Type_I')
# (709, 24.17851, 1.589027, 80.553067, 'no', 'Obesity_Type_I')
# (710, 18.0, 1.692242, 90.019501, 'no', 'Obesity_Type_I')
# (711, 18.0, 1.683, 90.924208, 'no', 'Obesity_Type_I')
# (712, 20.206358, 1.738397, 93.890682, 'no', 'Obesity_Type_I')
# (713, 18.152876, 1.694969, 92.508122, 'no', 'Obesity_Type_I')
# (714, 19.374207, 1.632605, 82.0, 'no', 'Obesity_Type_I')
# (715, 19.275687, 1.623377, 82.851318, 'no', 'Obesity_Type_I')
# (716, 22.956845, 1.618686, 81.281578, 'no', 'Obesity_Type_I')
# (717, 22.829681, 1.616085, 82.582954, 'no', 'Obesity_Type_I')
# (718, 39.29266, 1.567131, 80.0, 'no', 'Obesity_Type_I')
# (719, 37.872971, 1.565366, 80.0, 'no', 'Obesity_Type_I')
# (720, 37.613378, 1.516007, 77.033049, 'no', 'Obesity_Type_I')
# (721, 37.471683, 1.549812, 76.082517, 'no', 'Obesity_Type_I')
# (722, 39.12631, 1.562889, 76.65949, 'no', 'Obesity_Type_I')
# (723, 37.063599, 1.502609, 75.279605, 'no', 'Obesity_Type_I')
# (724, 41.318302, 1.544937, 77.053948, 'no', 'Obesity_Type_I')
# (725, 43.726081, 1.592316, 77.00103, 'no', 'Obesity_Type_I')
# (726, 18.0, 1.692913, 89.93889, 'no', 'Obesity_Type_I')
# (727, 18.0, 1.668555, 85.607466, 'no', 'Obesity_Type_I')
# (728, 18.024744, 1.617192, 83.121811, 'no', 'Obesity_Type_I')
# (729, 18.10682, 1.602129, 82.412665, 'no', 'Obesity_Type_I')
# (730, 19.045357, 1.61291, 82.193405, 'no', 'Obesity_Type_I')
# (731, 18.945961, 1.605469, 82.039, 'no', 'Obesity_Type_I')
# (732, 25.919241, 1.611462, 102.093223, 'no', 'Obesity_Type_III')
# (733, 26.0, 1.584782, 105.055597, 'no', 'Obesity_Type_III')
# (734, 18.233541, 1.792378, 137.859737, 'no', 'Obesity_Type_III')
# (735, 18.147705, 1.802257, 149.935848, 'no', 'Obesity_Type_III')
# (736, 26.0, 1.65632, 111.93301, 'no', 'Obesity_Type_III')
# (737, 26.0, 1.600762, 105.448264, 'no', 'Obesity_Type_III')
# (738, 25.902283, 1.678658, 104.954834, 'no', 'Obesity_Type_III')
# (739, 25.540865, 1.678201, 109.900472, 'no', 'Obesity_Type_III')
# (740, 22.39251, 1.65563, 121.205171, 'no', 'Obesity_Type_III')
# (741, 21.305402, 1.694952, 133.76473, 'no', 'Obesity_Type_III')
# (742, 26.0, 1.622771, 109.959714, 'no', 'Obesity_Type_III')
# (743, 26.0, 1.583889, 110.545378, 'no', 'Obesity_Type_III')
# (744, 21.334585, 1.729045, 131.529267, 'no', 'Obesity_Type_III')
# (745, 22.978655, 1.664622, 114.465425, 'no', 'Obesity_Type_III')
# (746, 21.01245, 1.747773, 127.902844, 'no', 'Obesity_Type_III')
# (747, 21.056059, 1.730113, 152.094362, 'no', 'Obesity_Type_III')
# (748, 18.771001, 1.746652, 133.800129, 'no', 'Obesity_Type_III')
# (749, 24.265943, 1.719365, 114.511537, 'no', 'Obesity_Type_III')
# (750, 26.0, 1.632377, 111.946655, 'no', 'Obesity_Type_III')
# (751, 26.0, 1.642572, 111.868169, 'no', 'Obesity_Type_III')
# (752, 25.96701, 1.654875, 104.758713, 'no', 'Obesity_Type_III')
# (753, 26.0, 1.627567, 107.482662, 'no', 'Obesity_Type_III')
# (754, 20.590046, 1.736276, 130.927138, 'no', 'Obesity_Type_III')
# (755, 24.497373, 1.737056, 132.527011, 'no', 'Obesity_Type_III')
# (756, 25.991886, 1.580968, 102.003378, 'no', 'Obesity_Type_III')
# (757, 25.908431, 1.607128, 103.026858, 'no', 'Obesity_Type_III')
# (758, 18.177882, 1.821566, 142.102468, 'no', 'Obesity_Type_III')
# (759, 18.112503, 1.82773, 152.720545, 'no', 'Obesity_Type_III')
# (760, 26.0, 1.656504, 111.993054, 'no', 'Obesity_Type_III')
# (761, 26.0, 1.637725, 111.208963, 'no', 'Obesity_Type_III')
# (762, 25.902283, 1.669701, 104.585783, 'no', 'Obesity_Type_III')
# (763, 25.540865, 1.668709, 104.754958, 'no', 'Obesity_Type_III')
# (764, 20.520992, 1.668642, 124.704781, 'no', 'Obesity_Type_III')
# (765, 20.871153, 1.690614, 129.769141, 'no', 'Obesity_Type_III')
# (766, 26.0, 1.622418, 110.676343, 'no', 'Obesity_Type_III')
# (767, 26.0, 1.643332, 110.824698, 'no', 'Obesity_Type_III')
# (768, 21.768834, 1.733383, 135.524857, 'no', 'Obesity_Type_III')
# (769, 20.891491, 1.748313, 133.573787, 'no', 'Obesity_Type_III')
# (770, 20.941943, 1.812963, 138.730619, 'no', 'Obesity_Type_III')
# (771, 20.989016, 1.80734, 155.872093, 'no', 'Obesity_Type_III')
# (772, 18.367481, 1.745644, 133.665587, 'no', 'Obesity_Type_III')
# (773, 21.051107, 1.753266, 133.852432, 'no', 'Obesity_Type_III')
# (774, 26.0, 1.632193, 111.886611, 'no', 'Obesity_Type_III')
# (775, 26.0, 1.641098, 111.818345, 'no', 'Obesity_Type_III')
# (776, 25.998646, 1.640741, 104.808542, 'no', 'Obesity_Type_III')
# (777, 26.0, 1.618573, 104.928643, 'no', 'Obesity_Type_III')
# (778, 22.846357, 1.757442, 133.365094, 'no', 'Obesity_Type_III')
# (779, 19.885655, 1.763343, 133.952675, 'no', 'Obesity_Type_III')
# (780, 25.930376, 1.610086, 102.38745, 'no', 'Obesity_Type_III')
# (781, 25.897815, 1.664463, 102.781971, 'no', 'Obesity_Type_III')
# (782, 26.0, 1.602025, 104.899348, 'no', 'Obesity_Type_III')
# (783, 25.968792, 1.632896, 104.988925, 'no', 'Obesity_Type_III')
# (784, 18.335019, 1.771043, 137.044959, 'no', 'Obesity_Type_III')
# (785, 21.700748, 1.789555, 137.767787, 'no', 'Obesity_Type_III')
# (786, 18.222536, 1.801746, 141.166265, 'no', 'Obesity_Type_III')
# (787, 20.3756, 1.787195, 151.975864, 'no', 'Obesity_Type_III')
# (788, 26.0, 1.644141, 111.942544, 'no', 'Obesity_Type_III')
# (789, 26.0, 1.643355, 111.600553, 'no', 'Obesity_Type_III')
# (790, 26.0, 1.623707, 105.037463, 'no', 'Obesity_Type_III')
# (791, 26.0, 1.610636, 105.423532, 'no', 'Obesity_Type_III')
# (792, 25.943827, 1.629491, 104.839068, 'no', 'Obesity_Type_III')
# (793, 25.291974, 1.684768, 104.821175, 'no', 'Obesity_Type_III')
# (794, 25.653233, 1.66494, 110.92217, 'no', 'Obesity_Type_III')
# (795, 25.783865, 1.655646, 110.21734, 'no', 'Obesity_Type_III')
# (796, 19.17614, 1.666194, 124.805868, 'no', 'Obesity_Type_III')
# (797, 21.207423, 1.707508, 121.864326, 'no', 'Obesity_Type_III')
# (798, 21.633056, 1.754174, 133.783955, 'no', 'Obesity_Type_III')
# (799, 21.009596, 1.714193, 131.866734, 'no', 'Obesity_Type_III')
# (800, 26.0, 1.62439, 110.008636, 'no', 'Obesity_Type_III')
# (801, 26.0, 1.638836, 110.970479, 'no', 'Obesity_Type_III')
# (802, 26.0, 1.621245, 111.267334, 'no', 'Obesity_Type_III')
# (803, 25.954511, 1.623514, 109.980145, 'no', 'Obesity_Type_III')
# (804, 21.001969, 1.736215, 132.145549, 'no', 'Obesity_Type_III')
# (805, 21.772251, 1.732951, 132.904884, 'no', 'Obesity_Type_III')
# (806, 23.76197, 1.69135, 114.480696, 'no', 'Obesity_Type_III')
# (807, 24.449655, 1.635062, 113.277388, 'no', 'Obesity_Type_III')
# (808, 18.378203, 1.746061, 128.261402, 'no', 'Obesity_Type_III')
# (809, 19.725718, 1.746529, 129.363771, 'no', 'Obesity_Type_III')
# (810, 21.344018, 1.746516, 144.302261, 'no', 'Obesity_Type_III')
# (811, 21.322097, 1.751118, 149.291106, 'no', 'Obesity_Type_III')
# (812, 19.262934, 1.741014, 132.57927, 'no', 'Obesity_Type_III')
# (813, 21.566815, 1.748533, 133.94608, 'no', 'Obesity_Type_III')
# (814, 24.475242, 1.694726, 112.776612, 'no', 'Obesity_Type_III')
# (815, 25.612462, 1.674515, 112.879662, 'no', 'Obesity_Type_III')
# (816, 26.0, 1.631332, 111.829957, 'no', 'Obesity_Type_III')
# (817, 26.0, 1.641918, 111.86899, 'no', 'Obesity_Type_III')
# (818, 26.0, 1.640125, 111.539494, 'no', 'Obesity_Type_III')
# (819, 26.0, 1.649178, 111.914361, 'no', 'Obesity_Type_III')
# (820, 25.96773, 1.603404, 105.031908, 'no', 'Obesity_Type_III')
# (821, 25.989938, 1.644199, 105.036075, 'no', 'Obesity_Type_III')
# (822, 26.0, 1.628909, 106.875927, 'no', 'Obesity_Type_III')
# (823, 25.617227, 1.628019, 108.265922, 'no', 'Obesity_Type_III')
# (824, 21.030909, 1.71818, 133.466763, 'no', 'Obesity_Type_III')
# (825, 20.951084, 1.708581, 131.274851, 'no', 'Obesity_Type_III')
# (826, 22.980221, 1.724983, 132.94066, 'no', 'Obesity_Type_III')
# (827, 23.426036, 1.739991, 133.485478, 'no', 'Obesity_Type_III')
# (828, 25.999185, 1.568543, 102.000122, 'no', 'Obesity_Type_III')
# (829, 25.934757, 1.579893, 102.134646, 'no', 'Obesity_Type_III')
# (830, 20.327723, 1.782714, 154.618446, 'no', 'Obesity_Type_III')
# (831, 19.47219, 1.793824, 160.935351, 'no', 'Obesity_Type_III')
# (832, 26.0, 1.659557, 111.999096, 'no', 'Obesity_Type_III')
# (833, 26.0, 1.65782, 111.95611, 'no', 'Obesity_Type_III')
# (834, 25.816445, 1.684082, 104.592372, 'no', 'Obesity_Type_III')
# (835, 25.498965, 1.68395, 104.846817, 'no', 'Obesity_Type_III')
# (836, 19.137495, 1.716521, 127.642324, 'no', 'Obesity_Type_III')
# (837, 20.190733, 1.680762, 125.418548, 'no', 'Obesity_Type_III')
# (838, 26.0, 1.623303, 110.81746, 'no', 'Obesity_Type_III')
# (839, 26.0, 1.631856, 110.804337, 'no', 'Obesity_Type_III')
# (840, 21.840654, 1.747479, 136.516648, 'no', 'Obesity_Type_III')
# (841, 20.871667, 1.782453, 137.852618, 'no', 'Obesity_Type_III')
# (842, 21.501721, 1.809871, 152.394739, 'no', 'Obesity_Type_III')
# (843, 21.521294, 1.803677, 160.639405, 'no', 'Obesity_Type_III')
# (844, 18.314593, 1.745602, 133.554686, 'no', 'Obesity_Type_III')
# (845, 19.529746, 1.751038, 133.843033, 'no', 'Obesity_Type_III')
# (846, 26.0, 1.631547, 111.588625, 'no', 'Obesity_Type_III')
# (847, 26.0, 1.635905, 111.571076, 'no', 'Obesity_Type_III')
# (848, 26.0, 1.616975, 104.846218, 'no', 'Obesity_Type_III')
# (849, 26.0, 1.62788, 104.92057, 'no', 'Obesity_Type_III')
# (850, 21.768153, 1.76416, 133.888629, 'no', 'Obesity_Type_III')
# (851, 21.238416, 1.763847, 133.937873, 'no', 'Obesity_Type_III')
# (852, 25.930376, 1.608808, 102.083964, 'no', 'Obesity_Type_III')
# (853, 25.919571, 1.610488, 102.174953, 'no', 'Obesity_Type_III')
# (854, 25.918524, 1.621231, 104.986792, 'no', 'Obesity_Type_III')
# (855, 25.565662, 1.642392, 104.988082, 'no', 'Obesity_Type_III')
# (856, 18.744914, 1.801983, 138.034526, 'no', 'Obesity_Type_III')
# (857, 21.704699, 1.787614, 137.858254, 'no', 'Obesity_Type_III')
# (858, 20.089969, 1.801478, 151.417292, 'no', 'Obesity_Type_III')
# (859, 18.120739, 1.807576, 152.567671, 'no', 'Obesity_Type_III')
# (860, 26.0, 1.650125, 111.939671, 'no', 'Obesity_Type_III')
# (861, 26.0, 1.652674, 111.919155, 'no', 'Obesity_Type_III')
# (862, 25.986185, 1.663632, 105.122109, 'no', 'Obesity_Type_III')
# (863, 25.982113, 1.627818, 105.428628, 'no', 'Obesity_Type_III')
# (864, 25.748627, 1.66877, 104.774144, 'no', 'Obesity_Type_III')
# (865, 25.959772, 1.642098, 104.966758, 'no', 'Obesity_Type_III')
# (866, 25.653233, 1.65757, 109.931233, 'no', 'Obesity_Type_III')
# (867, 25.783865, 1.643111, 109.910012, 'no', 'Obesity_Type_III')
# (868, 21.412434, 1.675562, 121.639178, 'no', 'Obesity_Type_III')
# (869, 22.77789, 1.661415, 120.748213, 'no', 'Obesity_Type_III')
# (870, 21.140165, 1.713133, 133.735889, 'no', 'Obesity_Type_III')
# (871, 21.413498, 1.7199, 133.886031, 'no', 'Obesity_Type_III')
# (872, 26.0, 1.622701, 109.982692, 'no', 'Obesity_Type_III')
# (873, 26.0, 1.622468, 110.400847, 'no', 'Obesity_Type_III')
# (874, 26.0, 1.618867, 110.777391, 'no', 'Obesity_Type_III')
# (875, 26.0, 1.600905, 110.074946, 'no', 'Obesity_Type_III')
# (876, 21.391371, 1.730636, 131.902591, 'no', 'Obesity_Type_III')
# (877, 21.051982, 1.729719, 131.877558, 'no', 'Obesity_Type_III')
# (878, 23.455303, 1.677672, 114.470482, 'no', 'Obesity_Type_III')
# (879, 23.69484, 1.637524, 113.90506, 'no', 'Obesity_Type_III')
# (880, 20.601222, 1.738717, 128.114161, 'no', 'Obesity_Type_III')
# (881, 20.81158, 1.741193, 128.763843, 'no', 'Obesity_Type_III')
# (882, 19.993565, 1.792833, 152.43563, 'no', 'Obesity_Type_III')
# (883, 20.074449, 1.810427, 152.217135, 'no', 'Obesity_Type_III')
# (884, 18.904037, 1.743589, 133.281333, 'no', 'Obesity_Type_III')
# (885, 19.783234, 1.747962, 133.936535, 'no', 'Obesity_Type_III')
# (886, 24.291205, 1.71146, 113.372851, 'no', 'Obesity_Type_III')
# (887, 25.311534, 1.685482, 113.451224, 'no', 'Obesity_Type_III')
# (888, 26.0, 1.639251, 111.927001, 'no', 'Obesity_Type_III')
# (889, 26.0, 1.654784, 111.933152, 'no', 'Obesity_Type_III')
# (890, 26.0, 1.641209, 111.856492, 'no', 'Obesity_Type_III')
# (891, 26.0, 1.643167, 111.894229, 'no', 'Obesity_Type_III')
# (892, 25.966504, 1.63073, 104.790549, 'no', 'Obesity_Type_III')
# (893, 25.950898, 1.649867, 104.791035, 'no', 'Obesity_Type_III')
# (894, 26.0, 1.613574, 107.012256, 'no', 'Obesity_Type_III')
# (895, 26.0, 1.627532, 106.69053, 'no', 'Obesity_Type_III')
# (896, 20.848608, 1.726606, 131.76807, 'no', 'Obesity_Type_III')
# (897, 20.801791, 1.721476, 131.042274, 'no', 'Obesity_Type_III')
# (898, 23.712641, 1.742901, 132.8071, 'no', 'Obesity_Type_III')
# (899, 24.063874, 1.737313, 133.166595, 'no', 'Obesity_Type_III')
# (900, 25.95774, 1.62414, 102.233445, 'no', 'Obesity_Type_III')
# (901, 25.909353, 1.644078, 102.277765, 'no', 'Obesity_Type_III')
# (902, 25.954995, 1.592529, 102.874549, 'no', 'Obesity_Type_III')
# (903, 25.908829, 1.607734, 102.305767, 'no', 'Obesity_Type_III')
# (904, 19.297004, 1.817271, 141.917802, 'no', 'Obesity_Type_III')
# (905, 18.301773, 1.808765, 140.292018, 'no', 'Obesity_Type_III')
# (906, 19.872667, 1.817231, 152.371911, 'no', 'Obesity_Type_III')
# (907, 18.13782, 1.819728, 151.278532, 'no', 'Obesity_Type_III')
# (908, 26.0, 1.656465, 111.949972, 'no', 'Obesity_Type_III')
# (909, 26.0, 1.648143, 111.950113, 'no', 'Obesity_Type_III')
# (910, 26.0, 1.622703, 111.216192, 'no', 'Obesity_Type_III')
# (911, 26.0, 1.640606, 111.036881, 'no', 'Obesity_Type_III')
# (912, 25.42724, 1.683502, 104.759643, 'no', 'Obesity_Type_III')
# (913, 25.795187, 1.669039, 104.593929, 'no', 'Obesity_Type_III')
# (914, 25.493586, 1.673665, 104.704707, 'no', 'Obesity_Type_III')
# (915, 25.524336, 1.668931, 104.768318, 'no', 'Obesity_Type_III')
# (916, 20.908785, 1.700996, 126.490236, 'no', 'Obesity_Type_III')
# (917, 20.781751, 1.734092, 125.117633, 'no', 'Obesity_Type_III')
# (918, 21.289104, 1.708291, 130.986338, 'no', 'Obesity_Type_III')
# (919, 21.210732, 1.716497, 130.871127, 'no', 'Obesity_Type_III')
# (920, 26.0, 1.62495, 111.00492, 'no', 'Obesity_Type_III')
# (921, 26.0, 1.594776, 110.640929, 'no', 'Obesity_Type_III')
# (922, 26.0, 1.626503, 110.818757, 'no', 'Obesity_Type_III')
# (923, 26.0, 1.624576, 110.803117, 'no', 'Obesity_Type_III')
# (924, 21.656907, 1.729099, 134.842656, 'no', 'Obesity_Type_III')
# (925, 21.760734, 1.73581, 135.346677, 'no', 'Obesity_Type_III')
# (926, 21.028989, 1.748524, 133.878843, 'no', 'Obesity_Type_III')
# (927, 21.282238, 1.748951, 133.662583, 'no', 'Obesity_Type_III')
# (928, 20.388049, 1.777971, 137.785027, 'no', 'Obesity_Type_III')
# (929, 21.022206, 1.73995, 135.693381, 'no', 'Obesity_Type_III')
# (930, 20.102241, 1.816868, 153.959945, 'no', 'Obesity_Type_III')
# (931, 21.291969, 1.8002, 155.242672, 'no', 'Obesity_Type_III')
# (932, 20.530998, 1.74647, 133.644711, 'no', 'Obesity_Type_III')
# (933, 18.976968, 1.759091, 133.903612, 'no', 'Obesity_Type_III')
# (934, 20.924956, 1.752531, 133.618706, 'no', 'Obesity_Type_III')
# (935, 21.28253, 1.761773, 133.903469, 'no', 'Obesity_Type_III')
# (936, 26.0, 1.633195, 111.883747, 'no', 'Obesity_Type_III')
# (937, 26.0, 1.633945, 111.9307, 'no', 'Obesity_Type_III')
# (938, 26.0, 1.641601, 111.830924, 'no', 'Obesity_Type_III')
# (939, 26.0, 1.641132, 111.841706, 'no', 'Obesity_Type_III')
# (940, 25.999174, 1.638218, 104.810024, 'no', 'Obesity_Type_III')
# (941, 25.999942, 1.627483, 104.881994, 'no', 'Obesity_Type_III')
# (942, 26.0, 1.610225, 104.936381, 'no', 'Obesity_Type_III')
# (943, 26.0, 1.61739, 105.013901, 'no', 'Obesity_Type_III')
# (944, 23.365041, 1.744319, 133.45249, 'no', 'Obesity_Type_III')
# (945, 23.421726, 1.755467, 133.478611, 'no', 'Obesity_Type_III')
# (946, 18.826782, 1.746416, 133.747012, 'no', 'Obesity_Type_III')
# (947, 18.94093, 1.746411, 133.676663, 'no', 'Obesity_Type_III')
# (948, 25.921678, 1.611452, 102.363149, 'no', 'Obesity_Type_III')
# (949, 25.940153, 1.596813, 102.320437, 'no', 'Obesity_Type_III')
# (950, 25.999636, 1.610126, 102.686908, 'no', 'Obesity_Type_III')
# (951, 25.907833, 1.623113, 102.555691, 'no', 'Obesity_Type_III')
# (952, 25.991194, 1.618348, 104.94582, 'no', 'Obesity_Type_III')
# (953, 25.993154, 1.609401, 104.854928, 'no', 'Obesity_Type_III')
# (954, 25.988668, 1.621671, 105.313967, 'no', 'Obesity_Type_III')
# (955, 25.976209, 1.614484, 104.999403, 'no', 'Obesity_Type_III')
# (956, 18.743587, 1.789143, 138.202869, 'no', 'Obesity_Type_III')
# (957, 20.323767, 1.774207, 138.143162, 'no', 'Obesity_Type_III')
# (958, 21.394047, 1.792933, 137.832414, 'no', 'Obesity_Type_III')
# (959, 21.838323, 1.758959, 137.79299, 'no', 'Obesity_Type_III')
# (960, 18.20634, 1.807406, 141.799429, 'no', 'Obesity_Type_III')
# (961, 18.532826, 1.75091, 142.545183, 'no', 'Obesity_Type_III')
# (962, 20.438478, 1.805803, 153.149491, 'no', 'Obesity_Type_III')
# (963, 20.796266, 1.796538, 152.473675, 'no', 'Obesity_Type_III')
# (964, 26.0, 1.634894, 111.946321, 'no', 'Obesity_Type_III')
# (965, 26.0, 1.639524, 111.945588, 'no', 'Obesity_Type_III')
# (966, 26.0, 1.643017, 111.720238, 'no', 'Obesity_Type_III')
# (967, 26.0, 1.641849, 111.682693, 'no', 'Obesity_Type_III')
# (968, 26.0, 1.621167, 104.947703, 'no', 'Obesity_Type_III')
# (969, 25.992898, 1.638075, 105.036522, 'no', 'Obesity_Type_III')
# (970, 26.0, 1.60937, 105.407313, 'no', 'Obesity_Type_III')
# (971, 26.0, 1.608283, 105.359688, 'no', 'Obesity_Type_III')
# (972, 25.951737, 1.629442, 104.835346, 'no', 'Obesity_Type_III')
# (973, 25.982261, 1.629225, 104.838425, 'no', 'Obesity_Type_III')
# (974, 25.470652, 1.680218, 104.807284, 'no', 'Obesity_Type_III')
# (975, 25.289428, 1.686033, 104.772164, 'no', 'Obesity_Type_III')
# (976, 25.696073, 1.662978, 110.930509, 'no', 'Obesity_Type_III')
# (977, 25.561868, 1.675185, 110.621723, 'no', 'Obesity_Type_III')
# (978, 25.834018, 1.62456, 110.10589, 'no', 'Obesity_Type_III')
# (979, 25.895546, 1.626179, 110.074019, 'no', 'Obesity_Type_III')
# (980, 19.035557, 1.682594, 127.427458, 'no', 'Obesity_Type_III')
# (981, 18.634286, 1.669354, 126.088301, 'no', 'Obesity_Type_III')
# (982, 20.700876, 1.68838, 121.889803, 'no', 'Obesity_Type_III')
# (983, 20.741442, 1.694439, 122.813033, 'no', 'Obesity_Type_III')
# (984, 21.695892, 1.755476, 133.870501, 'no', 'Obesity_Type_III')
# (985, 21.635977, 1.748106, 133.259033, 'no', 'Obesity_Type_III')
# (986, 21.232659, 1.719913, 131.567481, 'no', 'Obesity_Type_III')
# (987, 21.008297, 1.723587, 131.929712, 'no', 'Obesity_Type_III')
# (988, 25.962949, 1.623812, 109.996742, 'no', 'Obesity_Type_III')
# (989, 26.0, 1.624099, 109.978402, 'no', 'Obesity_Type_III')
# (990, 26.0, 1.632983, 111.157811, 'no', 'Obesity_Type_III')
# (991, 26.0, 1.640745, 110.919646, 'no', 'Obesity_Type_III')
# (992, 26.0, 1.629727, 111.275646, 'no', 'Obesity_Type_III')
# (993, 26.0, 1.624134, 111.531208, 'no', 'Obesity_Type_III')
# (994, 25.964788, 1.623938, 109.984263, 'no', 'Obesity_Type_III')
# (995, 25.994949, 1.593321, 110.168166, 'no', 'Obesity_Type_III')
# (996, 20.952737, 1.730333, 132.116491, 'no', 'Obesity_Type_III')
# (997, 20.978166, 1.721057, 132.054793, 'no', 'Obesity_Type_III')
# (998, 21.67447, 1.71978, 132.262558, 'no', 'Obesity_Type_III')
# (999, 21.568951, 1.699315, 133.10761, 'no', 'Obesity_Type_III')
# (1000, 23.647935, 1.681394, 114.479459, 'no', 'Obesity_Type_III')
# (1001, 24.196367, 1.697421, 114.482386, 'no', 'Obesity_Type_III')
# (1002, 24.284833, 1.650726, 113.774198, 'no', 'Obesity_Type_III')
# (1003, 24.693108, 1.667383, 112.982549, 'no', 'Obesity_Type_III')
# (1004, 18.862264, 1.746277, 128.705761, 'no', 'Obesity_Type_III')
# (1005, 18.423482, 1.735461, 126.798173, 'no', 'Obesity_Type_III')
# (1006, 20.394082, 1.747714, 128.148108, 'no', 'Obesity_Type_III')
# (1007, 20.217015, 1.71582, 129.466541, 'no', 'Obesity_Type_III')
# (1008, 21.330178, 1.747987, 147.296186, 'no', 'Obesity_Type_III')
# (1009, 19.528936, 1.817917, 142.559161, 'no', 'Obesity_Type_III')
# (1010, 19.364339, 1.80835, 150.51648, 'no', 'Obesity_Type_III')
# (1011, 21.131526, 1.739457, 150.37757, 'no', 'Obesity_Type_III')
# (1012, 19.012872, 1.742062, 133.779919, 'no', 'Obesity_Type_III')
# (1013, 18.469086, 1.741925, 133.017105, 'no', 'Obesity_Type_III')
# (1014, 21.572114, 1.751067, 133.845064, 'no', 'Obesity_Type_III')
# (1015, 21.680123, 1.749118, 133.955091, 'no', 'Obesity_Type_III')
# (1016, 24.469756, 1.663341, 113.077187, 'no', 'Obesity_Type_III')
# (1017, 25.12791, 1.668537, 112.555456, 'no', 'Obesity_Type_III')
# (1018, 25.986368, 1.668951, 112.249699, 'no', 'Obesity_Type_III')
# (1019, 25.951979, 1.661712, 112.098616, 'no', 'Obesity_Type_III')
# (1020, 26.0, 1.633442, 111.821817, 'no', 'Obesity_Type_III')
# (1021, 26.0, 1.63302, 111.863186, 'no', 'Obesity_Type_III')
# (1022, 26.0, 1.633887, 111.878132, 'no', 'Obesity_Type_III')
# (1023, 26.0, 1.643421, 111.939983, 'no', 'Obesity_Type_III')
# (1024, 26.0, 1.640535, 111.555967, 'no', 'Obesity_Type_III')
# (1025, 26.0, 1.626483, 111.357062, 'no', 'Obesity_Type_III')
# (1026, 26.0, 1.64599, 111.922491, 'no', 'Obesity_Type_III')
# (1027, 26.0, 1.643892, 111.884535, 'no', 'Obesity_Type_III')
# (1028, 25.97731, 1.617817, 104.950776, 'no', 'Obesity_Type_III')
# (1029, 25.955014, 1.626449, 104.879602, 'no', 'Obesity_Type_III')
# (1030, 25.996716, 1.62658, 105.037203, 'no', 'Obesity_Type_III')
# (1031, 25.992348, 1.606474, 104.954291, 'no', 'Obesity_Type_III')
# (1032, 25.974446, 1.628855, 108.090006, 'no', 'Obesity_Type_III')
# (1033, 25.777565, 1.628205, 107.378702, 'no', 'Obesity_Type_III')
# (1034, 25.722004, 1.62847, 107.218949, 'no', 'Obesity_Type_III')
# (1035, 25.765628, 1.627839, 108.10736, 'no', 'Obesity_Type_III')
# (1036, 21.016849, 1.724268, 133.033523, 'no', 'Obesity_Type_III')
# (1037, 21.682367, 1.732383, 133.043941, 'no', 'Obesity_Type_III')
# (1038, 21.285965, 1.72692, 131.335786, 'no', 'Obesity_Type_III')
# (1039, 20.976842, 1.71073, 131.408528, 'no', 'Obesity_Type_III')
# (1040, 21.982942, 1.748584, 133.742943, 'no', 'Obesity_Type_III')
# (1041, 22.524036, 1.752206, 133.689352, 'no', 'Obesity_Type_III')
# (1042, 24.361936, 1.73945, 133.346641, 'no', 'Obesity_Type_III')
# (1043, 23.664709, 1.738836, 133.472641, 'no', 'Obesity_Type_III')

# %% [markdown]
# Write data in a csv file

# %%
csvfile = open('clear_new.csv', 'w') 
csv_writer = csv.writer(csvfile, lineterminator='\r')
# Now we can write data to files using two methods:
# writerow() or writerows() 
# writerow() is used when we need to write one-dimension data such as a single list :[1, ‘Jerry’, 95] 
# writerows() is used when we need to write multi-dimension data such as list of list [[1, ‘Jerry’, 95], [2, ‘Tom’, 80], [3, ‘Scooby’, 90]]  
# So the only difference is that writerows() lets you pass multiple values! 
csv_writer.writerow(['Age', 'Height', 'Weight', 'SMOKE', 'NObeyesdad'])
csv_writer.writerows(clear_sql_data)
csvfile.close()
